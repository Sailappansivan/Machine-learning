# %% [markdown]
# <a href="https://colab.research.google.com/github/Sailappansivan/Machine-learning/blob/new-branch/Copy_of_Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://raw.githubusercontent.com/Sailappansivan/Machine-learning/refs/heads/new-branch/1719219914-Analysis%20of%20Super%20Store%20-%20DA%20(1).csv
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `git clone https://raw.githubusercontent.com/Sailappansivan/Machine-learning/refs/heads/new-branch/1719219914-Analysis%20of%20Super%20Store%20-%20DA%20(1).csv'

# %%
# !git clone https://github.com/Sailappansivan/Machine-learning.git
# Out:
# fatal: destination path 'Machine-learning' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/Sailappansivan/Machine-learning.git
# Out:
# fatal: destination path 'Machine-learning' already exists and is not an empty directory.

# %%
df = pd.read_csv('/content/Machine-learning/Analysis of Super Store.csv')

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df = df[["Profit", "Sales"]] # data that has to be initiated or predict panapora data

# %%
df
# Out:
#         Profit     Sales
# 0      41.9136  261.9600
# 1     219.5820  731.9400
# 2       6.8714   14.6200
# 3    -383.0310  957.5775
# 4       2.5164   22.3680
# ...        ...       ...
# 9989    4.1028   25.2480
# 9990   15.6332   91.9600
# 9991   19.3932  258.5760
# 9992   13.3200   29.6000
# 9993   72.9480  243.1600
#
# [9994 rows x 2 columns]

# %%
df.plot(kind="box") #out of order
plt.show()

# %%
df.corr() #corr relation coefficient
# Out:
#           Profit     Sales
# Profit  1.000000  0.479064
# Sales   0.479064  1.000000

# %%
 X = df["Profit"]
 y = df["Sales"]

# %%
plt.scatter(X, y)
plt.xlabel("Profit")
plt.ylabel("Sales")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test ,y_train ,y_test = train_test_split(X, y, test_size=0.3, random_state=45)

# %%
X_train
# Out:
# 6993     79.7580
# 3077   -140.1960
# 7932     34.2940
# 5640     10.0800
# 439       2.3094
#           ...
# 8772     23.2350
# 163       9.6880
# 6012     35.9850
# 6558    169.1820
# 7115      2.0048
# Name: Profit, Length: 6995, dtype: float64

# %%
y_train
# Out:
# 6993     265.860
# 3077     981.372
# 7932     105.520
# 5640      28.800
# 439      207.846
#           ...
# 8772      74.352
# 163       27.680
# 6012     287.880
# 6558    1522.638
# 7115       5.728
# Name: Sales, Length: 6995, dtype: float64

# %%
X_train = np.array(X_train).reshape(-1, 1)
X_train
# Out:
# array([[  79.758 ],
#        [-140.196 ],
#        [  34.294 ],
#        ...,
#        [  35.985 ],
#        [ 169.182 ],
#        [   2.0048]])

# %%
X_test = np.array(X_test).reshape(-1, 1)
X_test
# Out:
# array([[ 5.4896],
#        [33.777 ],
#        [35.988 ],
#        ...,
#        [ 0.9772],
#        [14.346 ],
#        [ 9.1776]])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_
m = lr.coef_

# %%
c,m
# Out:
# (199.54951091855781, array([1.16390977]))

# %%
y_train_predict = lr.predict(X_train)

# %%
y_train_predict.flatten()
# Out:
# array([292.38062624,  36.374017  , 239.46463252, ..., 241.43280394,
#        396.46209339, 201.88291722])

# %%
plt.scatter(X_train, y_train)
plt.xlabel("Profit")
plt.ylabel("Sales")
plt.plot(X_train, y_train_predict, color="red")
plt.show()

# %%
df
# Out:
#         Profit     Sales
# 0      41.9136  261.9600
# 1     219.5820  731.9400
# 2       6.8714   14.6200
# 3    -383.0310  957.5775
# 4       2.5164   22.3680
# ...        ...       ...
# 9989    4.1028   25.2480
# 9990   15.6332   91.9600
# 9991   19.3932  258.5760
# 9992   13.3200   29.6000
# 9993   72.9480  243.1600
#
# [9994 rows x 2 columns]

# %%
X_test
# Out:
# array([[ 5.4896],
#        [33.777 ],
#        [35.988 ],
#        ...,
#        [ 0.9772],
#        [14.346 ],
#        [ 9.1776]])

# %%
y_pred_test = lr.predict([[24]])
y_pred_test
# Out:
# array([227.48334537])

# %%
"""y_pred_test = lr.predict(X_test)
y_pred_test"""
# Out:
# array([205.93890998, 238.86289117, 241.43629567, ..., 200.68688354,
#        216.24696046, 210.23140921])

# %%
plt.scatter(X_train, y_train)
plt.xlabel("Profit")
plt.ylabel("Sales")
plt.plot(X_test, y_pred_test, color="red")
plt.show()
